# %% [markdown]
# # In vitro assay analysis
#
#
# ## Directory structure
#
# Data is organized in the following structure:
#
# ```
# data/
# ├── metadata.csv
# ├── images/
# │   ├── 1_bf.tif
# │   ├── 1_g.tif
# │   ├── 1_r.tif
# │   ├── 2_0.tif
# │   └── ...
#
# ## metadata.csv example
# figure_name,figure_id,channel,seeding_density,virus,cargo,dose_vg/well,image_time_h,receptor,include,notes
# 1_bf.tif,1,brightfield,0.5e5,AAV9,EGFP,0.5e10,24,EGFRvIII,1,
# 1_r.tif,1,brightfield,0.5e5,AAV9,EGFP,0.5e10,24,EGFRvIII,1,
# ```

# %%
import pandas as pd
from cellseg.metadata import metadata

data = '/Users/longwei/Desktop/janglab/figures/2026-05-22-in_vitro_assay_transduction_24h/'
meta = data + 'metadata.csv'
result = data + 'in_vitro_assay_results.csv'
# Load or generate metadata
df_metadata = metadata(data_dir=data, verbose=True)
print("\nMetadata:")
df_metadata
# Out:
# Looking for metadata file at: /Users/longwei/Desktop/janglab/figures/2026-05-22-in_vitro_assay_transduction_24h/metadata.csv
# Looking for images in: /Users/longwei/Desktop/janglab/figures/2026-05-22-in_vitro_assay_transduction_24h/images
# ✓ Found and loaded metadata file (144 rows)
#
# Metadata:
#       figure_name  figure_id  experiment_id magnification channel  \
# 0    Image001.tif          1              1            4x      bf
# 1    Image002.tif          2              1            4x       r
# 2    Image003.tif          3              1            4x       g
# 3    Image004.tif          4              2            4x      bf
# 4    Image005.tif          5              2            4x       r
# ..            ...        ...            ...           ...     ...
# 139  Image140.tif        140             47            4x       r
# 140  Image141.tif        141             47            4x       g
# 141  Image142.tif        142             48            4x      bf
# 142  Image143.tif        143             48            4x       r
# 143  Image144.tif        144             48            4x       g
#
#      seeding_density virus cargo  dose_vg/well  image_time_h  receptor  \
# 0              50000  AAV6  EGFP  5.000000e+10            24  EGFRvIII
# 1              50000  AAV6  EGFP  5.000000e+10            24  EGFRvIII
# 2              50000  AAV6  EGFP  5.000000e+10            24  EGFRvIII
# 3              50000  AAV6  EGFP  5.000000e+10            24  EGFRvIII
# 4              50000  AAV6  EGFP  5.000000e+10            24  EGFRvIII
# ..               ...   ...   ...           ...           ...       ...
# 139            50000  AAV9  EGFP  2.500000e+09            24   Control
# 140            50000  AAV9  EGFP  2.500000e+09            24   Control
# 141            50000  AAV9  EGFP  2.500000e+09            24   Control
# 142            50000  AAV9  EGFP  2.500000e+09            24   Control
# 143            50000  AAV9  EGFP  2.500000e+09            24   Control
#
#      include  notes
# 0          1    NaN
# 1          1    NaN
# 2          1    NaN
# 3          1    NaN
# 4          1    NaN
# ..       ...    ...
# 139        1    NaN
# 140        1    NaN
# 141        1    NaN
# 142        1    NaN
# 143        1    NaN
#
# [144 rows x 13 columns]

# %%
from cellseg.quant import assay_rg_overlap_analysis

df_results = assay_rg_overlap_analysis(
    df_metadata,
    image_directory=data + 'images/',
    output_file='rg_overlap_results.csv',
    bf_label='bf',
    r_label='r',
    g_label='g',
    r_channel=0,
    g_channel=1,
    min_r_intensity=0.05,
)
# Out:
# Processing RG overlap: 100%|██████████| 48/48 [01:36<00:00,  2.01s/it]

# %%
df_results
# Out:
#     experiment_id status error magnification  seeding_density virus cargo  \
# 0               1     ok                  4x            50000  AAV6  EGFP
# 1               2     ok                  4x            50000  AAV6  EGFP
# 2               3     ok                  4x            50000  AAV6  EGFP
# 3               4     ok                  4x            50000  AAV6  EGFP
# 4               5     ok                  4x            50000  AAV6  EGFP
# 5               6     ok                  4x            50000  AAV6  EGFP
# 6               7     ok                  4x            50000  AAV6  EGFP
# 7               8     ok                  4x            50000  AAV6  EGFP
# 8               9     ok                  4x            50000  AAV6  EGFP
# 9              10     ok                  4x            50000  AAV6  EGFP
# 10             11     ok                  4x            50000  AAV6  EGFP
# 11             12     ok                  4x            50000  AAV6  EGFP
# 12             13     ok                  4x            50000  AAV6  EGFP
# 13             14     ok                  4x            50000  AAV6  EGFP
# 14             15     ok                  4x            50000  AAV6  EGFP
# 15             16     ok                  4x            50000  AAV6  EGFP
# 16             17     ok                  4x            50000  AAV6  EGFP
# 17             18     ok                  4x            50000  AAV6  EGFP
# 18             19     ok                  4x            50000  AAV6  EGFP
# 19             20     ok                  4x            50000  AAV6  EGFP
# 20             21     ok                  4x            50000  AAV6  EGFP
# 21             22     ok                  4x            50000  AAV6  EGFP
# 22             23     ok                  4x            50000  AAV6  EGFP
# 23             24     ok                  4x            50000  AAV6  EGFP
# 24             25     ok                  4x            50000  AAV9  EGFP
# 25             26     ok                  4x            50000  AAV9  EGFP
# 26             27     ok                  4x            50000  AAV9  EGFP
# 27             28     ok                  4x            50000  AAV9  EGFP
# 28             29     ok                  4x            50000  AAV9  EGFP
# 29             30     ok                  4x            50000  AAV9  EGFP
# 30             31     ok                  4x            50000  AAV9  EGFP
# 31             32     ok                  4x            50000  AAV9  EGFP
# 32             33     ok                  4x            50000  AAV9  EGFP
# 33             34     ok                  4x            50000  AAV9  EGFP
# 34             35     ok                  4x            50000  AAV9  EGFP
# 35             36     ok                  4x            50000  AAV9  EGFP
# 36             37     ok                  4x            50000  AAV9  EGFP
# 37             38     ok                  4x            50000  AAV9  EGFP
# 38             39     ok                  4x            50000  AAV9  EGFP
# 39             40     ok                  4x            50000  AAV9  EGFP
# 40             41     ok                  4x            50000  AAV9  EGFP
# 41             42     ok                  4x            50000  AAV9  EGFP
# 42             43     ok                  4x            50000  AAV9  EGFP
# 43             44     ok                  4x            50000  AAV9  EGFP
# 44             45     ok                  4x            50000  AAV9  EGFP
# 45             46     ok                  4x            50000  AAV9  EGFP
# 46             47     ok                  4x            50000  AAV9  EGFP
# 47             48     ok                  4x            50000  AAV9  EGFP
#
#     dose_vg/well  image_time_h  receptor  ... bf_area r_area r_intensity  \
# 0   5.000000e+10            24  EGFRvIII  ...  136459  16787    0.151356
# 1   5.000000e+10            24  EGFRvIII  ...  125664  13186    0.152658
# 2   5.000000e+10            24  EGFRvIII  ...  127888  14772    0.164497
# 3   2.500000e+10            24  EGFRvIII  ...  115449  13761    0.167211
# 4   2.500000e+10            24  EGFRvIII  ...  108394  10982    0.124767
# 5   2.500000e+10            24  EGFRvIII  ...  113505  11571    0.150269
# 6   5.000000e+09            24  EGFRvIII  ...  143013  16510    0.179192
# 7   5.000000e+09            24  EGFRvIII  ...  111923  12129    0.149172
# 8   5.000000e+09            24  EGFRvIII  ...  109287  14027    0.160436
# 9   2.500000e+09            24  EGFRvIII  ...  137514  15740    0.173023
# 10  2.500000e+09            24  EGFRvIII  ...  129812  16789    0.168742
# 11  2.500000e+09            24  EGFRvIII  ...  121911  13991    0.145637
# 12  5.000000e+10            24   Control  ...  105857      0    0.011767
# 13  5.000000e+10            24   Control  ...  103031      0    0.011776
# 14  5.000000e+10            24   Control  ...  133190      0    0.025252
# 15  2.500000e+10            24   Control  ...   71842      0    0.011765
# 16  2.500000e+10            24   Control  ...  119220      0    0.011765
# 17  2.500000e+10            24   Control  ...  108169      0    0.013074
# 18  5.000000e+09            24   Control  ...  122554      0    0.011788
# 19  5.000000e+09            24   Control  ...  129442      0    0.011765
# 20  5.000000e+09            24   Control  ...  105970      0    0.011767
# 21  2.500000e+09            24   Control  ...  120023      0    0.011771
# 22  2.500000e+09            24   Control  ...  125492      0    0.011784
# 23  2.500000e+09            24   Control  ...   98134      0    0.011768
# 24  5.000000e+10            24  EGFRvIII  ...  163556  16364    0.155557
# 25  5.000000e+10            24  EGFRvIII  ...  147981  13778    0.163865
# 26  5.000000e+10            24  EGFRvIII  ...  132914  15682    0.169881
# 27  2.500000e+10            24  EGFRvIII  ...  147387  16116    0.159134
# 28  2.500000e+10            24  EGFRvIII  ...  108657  12576    0.139009
# 29  2.500000e+10            24  EGFRvIII  ...  130019  12588    0.151948
# 30  5.000000e+09            24  EGFRvIII  ...  133407  15752    0.171383
# 31  5.000000e+09            24  EGFRvIII  ...  116223  12721    0.121292
# 32  5.000000e+09            24  EGFRvIII  ...  109086  13236    0.156113
# 33  2.500000e+09            24  EGFRvIII  ...  131244  13587    0.138281
# 34  2.500000e+09            24  EGFRvIII  ...   84970  12242    0.119569
# 35  2.500000e+09            24  EGFRvIII  ...   98478  11537    0.109240
# 36  5.000000e+10            24   Control  ...  105908      0    0.011765
# 37  5.000000e+10            24   Control  ...   98509      0    0.011765
# 38  5.000000e+10            24   Control  ...  114877      0    0.013540
# 39  2.500000e+10            24   Control  ...   86217      0    0.011791
# 40  2.500000e+10            24   Control  ...   98575      0    0.011765
# 41  2.500000e+10            24   Control  ...   93039      0    0.011777
# 42  5.000000e+09            24   Control  ...   94812      0    0.011765
# 43  5.000000e+09            24   Control  ...   99374      0    0.011767
# 44  5.000000e+09            24   Control  ...   91434      0    0.011765
# 45  2.500000e+09            24   Control  ...   97769      0    0.011765
# 46  2.500000e+09            24   Control  ...  103084      0    0.011768
# 47  2.500000e+09            24   Control  ...   86540      0    0.011765
#
#     r_filter  g_area  overlapping_area  overlap_r  overlap_g  g_intensity_all  \
# 0      False   33144              4544   0.270686   0.137099         0.568936
# 1      False   31249              4242   0.321705   0.135748         0.592918
# 2      False   25374              3155   0.213580   0.124340         0.561718
# 3      False   21809              3632   0.263934   0.166537         0.398763
# 4      False   16033              3472   0.316154   0.216553         0.409681
# 5      False   18594              2735   0.236367   0.147090         0.400027
# 6      False   18690              3285   0.198970   0.175762         0.231612
# 7      False   13128              1935   0.159535   0.147395         0.247120
# 8      False   12586              2984   0.212733   0.237089         0.246273
# 9      False   11129              2187   0.138945   0.196514         0.196049
# 10     False   14553              2486   0.148073   0.170824         0.195691
# 11     False   18455              3537   0.252805   0.191655         0.185320
# 12      True   25037                 0        NaN   0.000000         0.551511
# 13      True   25025                 0        NaN   0.000000         0.564849
# 14      True   33827                 0        NaN   0.000000         0.554888
# 15      True   15438                 0        NaN   0.000000         0.336876
# 16      True   17831                 0        NaN   0.000000         0.416610
# 17      True   17597                 0        NaN   0.000000         0.394434
# 18      True   15093                 0        NaN   0.000000         0.227704
# 19      True   11249                 0        NaN   0.000000         0.229849
# 20      True   15550                 0        NaN   0.000000         0.201390
# 21      True   14238                 0        NaN   0.000000         0.187336
# 22      True   19620                 0        NaN   0.000000         0.149791
# 23      True    7835                 0        NaN   0.000000         0.175979
# 24     False    7766              2116   0.129308   0.272470         0.159086
# 25     False    8148              1631   0.118377   0.200172         0.174302
# 26     False   11049              1542   0.098329   0.139560         0.180397
# 27     False    7962              1168   0.072475   0.146697         0.118263
# 28     False   10395              1949   0.154978   0.187494         0.148535
# 29     False    7995               978   0.077693   0.122326         0.149486
# 30     False    3576               295   0.018728   0.082494         0.117172
# 31     False    1763               526   0.041349   0.298355         0.145756
# 32     False    2927               544   0.041100   0.185856         0.138743
# 33     False    3707               276   0.020314   0.074454         0.126700
# 34     False    1400               522   0.042640   0.372857         0.139359
# 35     False    2184                38   0.003294   0.017399         0.125806
# 36      True   12678                 0        NaN   0.000000         0.177145
# 37      True   12126                 0        NaN   0.000000         0.180760
# 38      True   12914                 0        NaN   0.000000         0.169485
# 39      True    7354                 0        NaN   0.000000         0.136917
# 40      True    8486                 0        NaN   0.000000         0.132615
# 41      True    4159                 0        NaN   0.000000         0.122953
# 42      True    1762                 0        NaN   0.000000         0.135877
# 43      True    3017                 0        NaN   0.000000         0.136702
# 44      True     925                 0        NaN   0.000000         0.138819
# 45      True    2308                 0        NaN   0.000000         0.133741
# 46      True    2340                 0        NaN   0.000000         0.131547
# 47      True    1267                 0        NaN   0.000000         0.128768
#
#     g_intensity_overlap
# 0              0.590942
# 1              0.593209
# 2              0.580006
# 3              0.404263
# 4              0.411714
# 5              0.422250
# 6              0.249400
# 7              0.297316
# 8              0.259902
# 9              0.223858
# 10             0.222862
# 11             0.213406
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24             0.196584
# 25             0.177740
# 26             0.192963
# 27             0.118836
# 28             0.158185
# 29             0.155475
# 30             0.116943
# 31             0.140580
# 32             0.139828
# 33             0.128645
# 34             0.139434
# 35             0.119608
# 36                  NaN
# 37                  NaN
# 38                  NaN
# 39                  NaN
# 40                  NaN
# 41                  NaN
# 42                  NaN
# 43                  NaN
# 44                  NaN
# 45                  NaN
# 46                  NaN
# 47                  NaN
#
# [48 rows x 23 columns]

# %%
import importlib
import cellseg.plot
importlib.reload(cellseg.plot)

from cellseg.plot import simple_bubble_plot
import bokeh.io
bokeh.io.output_notebook()

df_plot = df_results[df_results["status"] == "ok"].copy()
df_plot["g_area_over_bf"] = df_plot["g_area"] / df_plot["bf_area"]

df_plot = (
    df_plot
    .groupby(["virus", "receptor", "dose_vg/well"])
    .mean(numeric_only=True)
    .reset_index()
)

for receptor in ["EGFRvIII", "Control"]:
    p = simple_bubble_plot(
        df_plot[df_plot["receptor"] == receptor],
        x="virus",
        y="dose_vg/well",
        size="g_area_over_bf",
        color="g_intensity_all",
        x_order=["AAV6", "AAV9"],
        y_order=[5e10, 2.5e10, 5e9, 2.5e9],
        size_range=(5, 38),
        width=400,
        height=360,
        title=receptor,
    )
    p.yaxis.axis_label = "Dose (v.g./well)"
    bokeh.io.show(p)

print(df_plot.head())

p = simple_bubble_plot(
    df_plot[df_plot["receptor"] == "EGFRvIII"],
    x="virus",
    y="dose_vg/well",
    size="overlap_g",
    color="g_intensity_overlap",
    x_order=["AAV6", "AAV9"],
    y_order=[5e10, 2.5e10, 5e9, 2.5e9],
    size_range=(5, 38),
    width=400,
    height=360,
    title="EGFRvIII",
)
p.yaxis.axis_label = "Dose (v.g./well)"
bokeh.io.show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c1f7705e-b8b4-4ba1-a107-b8265b92968b">Loading BokehJS ...</span>
#     </div>
#   <div id="ed13adca-f942-445b-ab10-1c4576d41d27" data-root-id="p2755" style="display: contents;"></div>
#   <div id="f4b3cc2b-e018-4842-915f-5b34e51c510e" data-root-id="p2821" style="display: contents;"></div>
#   virus  receptor  dose_vg/well  experiment_id  seeding_density  image_time_h  \
# 0  AAV6   Control  2.500000e+09           23.0          50000.0          24.0
# 1  AAV6   Control  5.000000e+09           20.0          50000.0          24.0
# 2  AAV6   Control  2.500000e+10           17.0          50000.0          24.0
# 3  AAV6   Control  5.000000e+10           14.0          50000.0          24.0
# 4  AAV6  EGFRvIII  2.500000e+09           11.0          50000.0          24.0
#
#          bf_area        r_area  r_intensity  r_filter        g_area  \
# 0  114549.666667      0.000000     0.011774       1.0  13897.666667
# 1  119322.000000      0.000000     0.011773       1.0  13964.000000
# 2   99743.666667      0.000000     0.012201       1.0  16955.333333
# 3  114026.000000      0.000000     0.016265       1.0  27963.000000
# 4  129745.666667  15506.666667     0.162468       0.0  14712.333333
#
#    overlapping_area  overlap_r  overlap_g  g_intensity_all  \
# 0          0.000000        NaN   0.000000         0.171035
# 1          0.000000        NaN   0.000000         0.219648
# 2          0.000000        NaN   0.000000         0.382640
# 3          0.000000        NaN   0.000000         0.557083
# 4       2736.666667   0.179941   0.186331         0.192353
#
#    g_intensity_overlap  g_area_over_bf
# 0                  NaN        0.118271
# 1                  NaN        0.118932
# 2                  NaN        0.175711
# 3                  NaN        0.244460
# 4             0.220042        0.114806
#   <div id="d1720437-1bcd-4795-9a68-3d68e1719543" data-root-id="p2887" style="display: contents;"></div>
