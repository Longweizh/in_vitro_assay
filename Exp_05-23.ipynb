# %% [markdown]
# # In vitro assay analysis
#
#
# ## Directory structure
#
# Data is organized in the following structure:
#
# ```
# data/
# ├── metadata.csv
# ├── images/
# │   ├── 1_bf.tif
# │   ├── 1_g.tif
# │   ├── 1_r.tif
# │   ├── 2_0.tif
# │   └── ...
#
# ## metadata.csv example
# figure_name,figure_id,channel,seeding_density,virus,cargo,dose_vg/well,image_time_h,receptor,include,notes
# 1_bf.tif,1,brightfield,0.5e5,AAV9,EGFP,0.5e10,24,EGFRvIII,1,
# 1_r.tif,1,brightfield,0.5e5,AAV9,EGFP,0.5e10,24,EGFRvIII,1,
# ```

# %%
import pandas as pd
from cellseg.metadata import metadata

data = '/Users/longwei/Desktop/janglab/figures/2026-05-23-in_vitro_assay_transduction_48h/'
meta = data + 'metadata.csv'
result = data + 'in_vitro_assay_results.csv'
# Load or generate metadata
df_metadata = metadata(data_dir=data, verbose=True)
print("\nMetadata:")
df_metadata
# Out:
# Looking for metadata file at: /Users/longwei/Desktop/janglab/figures/2026-05-23-in_vitro_assay_transduction_48h/metadata.csv
# Looking for images in: /Users/longwei/Desktop/janglab/figures/2026-05-23-in_vitro_assay_transduction_48h/
# ✓ Found and loaded metadata file (144 rows)
#
# Metadata:
#       figure_name  figure_id  experiment_id magnification channel  \
# 0    Image001.tif          1              1            4x      bf
# 1    Image002.tif          2              1            4x       r
# 2    Image003.tif          3              1            4x       g
# 3    Image004.tif          4              2            4x      bf
# 4    Image005.tif          5              2            4x       r
# ..            ...        ...            ...           ...     ...
# 139  Image140.tif        140             47            4x       r
# 140  Image141.tif        141             47            4x       g
# 141  Image142.tif        142             48            4x      bf
# 142  Image143.tif        143             48            4x       r
# 143  Image144.tif        144             48            4x       g
#
#      seeding_density virus cargo  dose_vg/well  image_time_h  receptor  \
# 0              50000  AAV6  EGFP  5.000000e+10            48  EGFRvIII
# 1              50000  AAV6  EGFP  5.000000e+10            48  EGFRvIII
# 2              50000  AAV6  EGFP  5.000000e+10            48  EGFRvIII
# 3              50000  AAV6  EGFP  5.000000e+10            48  EGFRvIII
# 4              50000  AAV6  EGFP  5.000000e+10            48  EGFRvIII
# ..               ...   ...   ...           ...           ...       ...
# 139            50000  AAV9  EGFP  2.500000e+09            48   Control
# 140            50000  AAV9  EGFP  2.500000e+09            48   Control
# 141            50000  AAV9  EGFP  2.500000e+09            48   Control
# 142            50000  AAV9  EGFP  2.500000e+09            48   Control
# 143            50000  AAV9  EGFP  2.500000e+09            48   Control
#
#      include  notes
# 0          1    NaN
# 1          1    NaN
# 2          1    NaN
# 3          1    NaN
# 4          1    NaN
# ..       ...    ...
# 139        1    NaN
# 140        1    NaN
# 141        1    NaN
# 142        1    NaN
# 143        1    NaN
#
# [144 rows x 13 columns]

# %%
from cellseg.quant import assay_rg_overlap_analysis

df_results = assay_rg_overlap_analysis(
    df_metadata,
    image_directory=data,
    output_file='rg_overlap_results.csv',
    bf_label='bf',
    r_label='r',
    g_label='g',
    r_channel=0,
    g_channel=1,
    min_r_intensity=0.05,
)
# Out:
# Processing RG overlap: 100%|██████████| 48/48 [01:36<00:00,  2.02s/it]

# %%
df_results
# Out:
#     experiment_id status error magnification  seeding_density virus cargo  \
# 0               1     ok                  4x            50000  AAV6  EGFP
# 1               2     ok                  4x            50000  AAV6  EGFP
# 2               3     ok                  4x            50000  AAV6  EGFP
# 3               4     ok                  4x            50000  AAV6  EGFP
# 4               5     ok                  4x            50000  AAV6  EGFP
# 5               6     ok                  4x            50000  AAV6  EGFP
# 6               7     ok                  4x            50000  AAV6  EGFP
# 7               8     ok                  4x            50000  AAV6  EGFP
# 8               9     ok                  4x            50000  AAV6  EGFP
# 9              10     ok                  4x            50000  AAV6  EGFP
# 10             11     ok                  4x            50000  AAV6  EGFP
# 11             12     ok                  4x            50000  AAV6  EGFP
# 12             13     ok                  4x            50000  AAV6  EGFP
# 13             14     ok                  4x            50000  AAV6  EGFP
# 14             15     ok                  4x            50000  AAV6  EGFP
# 15             16     ok                  4x            50000  AAV6  EGFP
# 16             17     ok                  4x            50000  AAV6  EGFP
# 17             18     ok                  4x            50000  AAV6  EGFP
# 18             19     ok                  4x            50000  AAV6  EGFP
# 19             20     ok                  4x            50000  AAV6  EGFP
# 20             21     ok                  4x            50000  AAV6  EGFP
# 21             22     ok                  4x            50000  AAV6  EGFP
# 22             23     ok                  4x            50000  AAV6  EGFP
# 23             24     ok                  4x            50000  AAV6  EGFP
# 24             25     ok                  4x            50000  AAV9  EGFP
# 25             26     ok                  4x            50000  AAV9  EGFP
# 26             27     ok                  4x            50000  AAV9  EGFP
# 27             28     ok                  4x            50000  AAV9  EGFP
# 28             29     ok                  4x            50000  AAV9  EGFP
# 29             30     ok                  4x            50000  AAV9  EGFP
# 30             31     ok                  4x            50000  AAV9  EGFP
# 31             32     ok                  4x            50000  AAV9  EGFP
# 32             33     ok                  4x            50000  AAV9  EGFP
# 33             34     ok                  4x            50000  AAV9  EGFP
# 34             35     ok                  4x            50000  AAV9  EGFP
# 35             36     ok                  4x            50000  AAV9  EGFP
# 36             37     ok                  4x            50000  AAV9  EGFP
# 37             38     ok                  4x            50000  AAV9  EGFP
# 38             39     ok                  4x            50000  AAV9  EGFP
# 39             40     ok                  4x            50000  AAV9  EGFP
# 40             41     ok                  4x            50000  AAV9  EGFP
# 41             42     ok                  4x            50000  AAV9  EGFP
# 42             43     ok                  4x            50000  AAV9  EGFP
# 43             44     ok                  4x            50000  AAV9  EGFP
# 44             45     ok                  4x            50000  AAV9  EGFP
# 45             46     ok                  4x            50000  AAV9  EGFP
# 46             47     ok                  4x            50000  AAV9  EGFP
# 47             48     ok                  4x            50000  AAV9  EGFP
#
#     dose_vg/well  image_time_h  receptor  ... bf_area r_area r_intensity  \
# 0   5.000000e+10            48  EGFRvIII  ...  152820  11557    0.157596
# 1   5.000000e+10            48  EGFRvIII  ...  144481   9025    0.196124
# 2   5.000000e+10            48  EGFRvIII  ...  146380   8571    0.160161
# 3   2.500000e+10            48  EGFRvIII  ...  139295  10635    0.175226
# 4   2.500000e+10            48  EGFRvIII  ...  120479   8123    0.156298
# 5   2.500000e+10            48  EGFRvIII  ...   94438   5727    0.133704
# 6   5.000000e+09            48  EGFRvIII  ...  135149  12279    0.186255
# 7   5.000000e+09            48  EGFRvIII  ...  112191   8450    0.169181
# 8   5.000000e+09            48  EGFRvIII  ...  129449  11079    0.188582
# 9   2.500000e+09            48  EGFRvIII  ...  165814  13539    0.163974
# 10  2.500000e+09            48  EGFRvIII  ...  129296  10127    0.171945
# 11  2.500000e+09            48  EGFRvIII  ...  124857  10658    0.181294
# 12  5.000000e+10            48   Control  ...  106477      0    0.011786
# 13  5.000000e+10            48   Control  ...   99153      0    0.011778
# 14  5.000000e+10            48   Control  ...  110326      0    0.026159
# 15  2.500000e+10            48   Control  ...   90729      0    0.011764
# 16  2.500000e+10            48   Control  ...  106718      0    0.011765
# 17  2.500000e+10            48   Control  ...   98748      0    0.011765
# 18  5.000000e+09            48   Control  ...  112880      0    0.011765
# 19  5.000000e+09            48   Control  ...  110208      0    0.011765
# 20  5.000000e+09            48   Control  ...  100037      0    0.011773
# 21  2.500000e+09            48   Control  ...  115520      0    0.011774
# 22  2.500000e+09            48   Control  ...  107421      0    0.011546
# 23  2.500000e+09            48   Control  ...   95674      0    0.011765
# 24  5.000000e+10            48  EGFRvIII  ...  160975  10952    0.160972
# 25  5.000000e+10            48  EGFRvIII  ...  152397   9232    0.161421
# 26  5.000000e+10            48  EGFRvIII  ...  130534   9545    0.171545
# 27  2.500000e+10            48  EGFRvIII  ...  141676   9121    0.142594
# 28  2.500000e+10            48  EGFRvIII  ...  128533   8969    0.185708
# 29  2.500000e+10            48  EGFRvIII  ...  136607   8304    0.171090
# 30  5.000000e+09            48  EGFRvIII  ...  161285  12193    0.183713
# 31  5.000000e+09            48  EGFRvIII  ...  113765   7493    0.158119
# 32  5.000000e+09            48  EGFRvIII  ...  123163  10527    0.188463
# 33  2.500000e+09            48  EGFRvIII  ...  153473  10418    0.163827
# 34  2.500000e+09            48  EGFRvIII  ...  105604   5962    0.135075
# 35  2.500000e+09            48  EGFRvIII  ...  119790   7735    0.149037
# 36  5.000000e+10            48   Control  ...  109750      0    0.011765
# 37  5.000000e+10            48   Control  ...  103223      0    0.011765
# 38  5.000000e+10            48   Control  ...  123840      0    0.012310
# 39  2.500000e+10            48   Control  ...  104927      0    0.010856
# 40  2.500000e+10            48   Control  ...  107693      0    0.011765
# 41  2.500000e+10            48   Control  ...  107043      0    0.011292
# 42  5.000000e+09            48   Control  ...   85351      0    0.011769
# 43  5.000000e+09            48   Control  ...  100292      0    0.011549
# 44  5.000000e+09            48   Control  ...  106671      0    0.011765
# 45  2.500000e+09            48   Control  ...   88097      0    0.011817
# 46  2.500000e+09            48   Control  ...  105696      0    0.011768
# 47  2.500000e+09            48   Control  ...   98154      0    0.011765
#
#     r_filter  g_area  overlapping_area  overlap_r  overlap_g  g_intensity_all  \
# 0      False   54547              5516   0.477286   0.101124         0.719856
# 1      False   62083              5390   0.597230   0.086819         0.754932
# 2      False   56511              3768   0.439622   0.066677         0.716706
# 3      False   45279              5332   0.501363   0.117759         0.589745
# 4      False   45333              4580   0.563831   0.101030         0.605003
# 5      False   31499              2640   0.460974   0.083812         0.531799
# 6      False   38083              4162   0.338953   0.109288         0.394881
# 7      False   35192              3367   0.398462   0.095675         0.375889
# 8      False   35054              4727   0.426663   0.134849         0.385615
# 9      False   29198              3388   0.250240   0.116035         0.330782
# 10     False   32219              5306   0.523946   0.164685         0.328781
# 11     False   29053              2959   0.277632   0.101848         0.345820
# 12      True   47451                 0        NaN   0.000000         0.684300
# 13      True   39834                 0        NaN   0.000000         0.711886
# 14      True   51010                 0        NaN   0.000000         0.712561
# 15      True   28805                 0        NaN   0.000000         0.551641
# 16      True   39784                 0        NaN   0.000000         0.539008
# 17      True   37759                 0        NaN   0.000000         0.565802
# 18      True   33884                 0        NaN   0.000000         0.371235
# 19      True   34432                 0        NaN   0.000000         0.361778
# 20      True   28980                 0        NaN   0.000000         0.337901
# 21      True   26896                 0        NaN   0.000000         0.284414
# 22      True   20487                 0        NaN   0.000000         0.271692
# 23      True   21231                 0        NaN   0.000000         0.270482
# 24     False   18825              4236   0.386779   0.225020         0.253273
# 25     False   13927              1846   0.199957   0.132548         0.253078
# 26     False   15958              2321   0.243164   0.145444         0.279306
# 27     False   10187               592   0.064905   0.058113         0.186228
# 28     False   11655              2659   0.296466   0.228142         0.233605
# 29     False   10777               928   0.111753   0.086109         0.192429
# 30     False    8958               970   0.079554   0.108283         0.125587
# 31     False    7065              1441   0.192313   0.203963         0.121037
# 32     False    9131              1908   0.181248   0.208958         0.126693
# 33     False    6049               456   0.043770   0.075384         0.119659
# 34     False    6590              1198   0.200939   0.181791         0.136033
# 35     False    5887               787   0.101745   0.133684         0.126860
# 36      True   14089                 0        NaN   0.000000         0.267072
# 37      True   11708                 0        NaN   0.000000         0.261587
# 38      True   16286                 0        NaN   0.000000         0.291297
# 39      True   14225                 0        NaN   0.000000         0.181196
# 40      True   12732                 0        NaN   0.000000         0.191244
# 41      True    7458                 0        NaN   0.000000         0.201782
# 42      True    8997                 0        NaN   0.000000         0.132370
# 43      True   10010                 0        NaN   0.000000         0.134118
# 44      True    8732                 0        NaN   0.000000         0.126175
# 45      True    3645                 0        NaN   0.000000         0.132300
# 46      True    5323                 0        NaN   0.000000         0.135351
# 47      True    4256                 0        NaN   0.000000         0.128222
#
#     g_intensity_overlap
# 0              0.770331
# 1              0.834945
# 2              0.757251
# 3              0.663545
# 4              0.671862
# 5              0.544975
# 6              0.498398
# 7              0.499700
# 8              0.459360
# 9              0.435758
# 10             0.452889
# 11             0.460126
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24             0.307644
# 25             0.356642
# 26             0.331786
# 27             0.224470
# 28             0.328853
# 29             0.222029
# 30             0.122163
# 31             0.123520
# 32             0.133574
# 33             0.120055
# 34             0.140512
# 35             0.127658
# 36                  NaN
# 37                  NaN
# 38                  NaN
# 39                  NaN
# 40                  NaN
# 41                  NaN
# 42                  NaN
# 43                  NaN
# 44                  NaN
# 45                  NaN
# 46                  NaN
# 47                  NaN
#
# [48 rows x 23 columns]

# %%
import importlib
import cellseg.plot
importlib.reload(cellseg.plot)

from cellseg.plot import simple_bubble_plot
import bokeh.io
bokeh.io.output_notebook()

df_plot = df_results[df_results["status"] == "ok"].copy()
df_plot["g_area_over_bf"] = df_plot["g_area"] / df_plot["bf_area"]

df_plot = (
    df_plot
    .groupby(["virus", "receptor", "dose_vg/well"])
    .mean(numeric_only=True)
    .reset_index()
)

for receptor in ["EGFRvIII", "Control"]:
    p = simple_bubble_plot(
        df_plot[df_plot["receptor"] == receptor],
        x="virus",
        y="dose_vg/well",
        size="g_area_over_bf",
        color="g_intensity_all",
        x_order=["AAV6", "AAV9"],
        y_order=[5e10, 2.5e10, 5e9, 2.5e9],
        size_range=(5, 38),
        width=400,
        height=360,
        title=receptor,
    )
    p.yaxis.axis_label = "Dose (v.g./well)"
    bokeh.io.show(p)

print(df_plot.head())

p = simple_bubble_plot(
    df_plot[df_plot["receptor"] == "EGFRvIII"],
    x="virus",
    y="dose_vg/well",
    size="overlap_g",
    color="g_intensity_overlap",
    x_order=["AAV6", "AAV9"],
    y_order=[5e10, 2.5e10, 5e9, 2.5e9],
    size_range=(5, 38),
    width=400,
    height=360,
    title="EGFRvIII",
)
p.yaxis.axis_label = "Dose (v.g./well)"
bokeh.io.show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a3749495-0e70-40f1-b091-33f59308b98a">Loading BokehJS ...</span>
#     </div>
#   <div id="e4a6ebfb-1b12-4614-a197-e4ce9c6993ee" data-root-id="p1005" style="display: contents;"></div>
#   <div id="c02e5c23-7a62-4b42-9bda-a0922c2600a2" data-root-id="p1071" style="display: contents;"></div>
#   virus  receptor  dose_vg/well  experiment_id  seeding_density  image_time_h  \
# 0  AAV6   Control  2.500000e+09           23.0          50000.0          48.0
# 1  AAV6   Control  5.000000e+09           20.0          50000.0          48.0
# 2  AAV6   Control  2.500000e+10           17.0          50000.0          48.0
# 3  AAV6   Control  5.000000e+10           14.0          50000.0          48.0
# 4  AAV6  EGFRvIII  2.500000e+09           11.0          50000.0          48.0
#
#          bf_area        r_area  r_intensity  r_filter        g_area  \
# 0  106205.000000      0.000000     0.011695       1.0  22871.333333
# 1  107708.333333      0.000000     0.011767       1.0  32432.000000
# 2   98731.666667      0.000000     0.011764       1.0  35449.333333
# 3  105318.666667      0.000000     0.016575       1.0  46098.333333
# 4  139989.000000  11441.333333     0.172404       0.0  30156.666667
#
#    overlapping_area  overlap_r  overlap_g  g_intensity_all  \
# 0          0.000000        NaN   0.000000         0.275529
# 1          0.000000        NaN   0.000000         0.356971
# 2          0.000000        NaN   0.000000         0.552150
# 3          0.000000        NaN   0.000000         0.702916
# 4       3884.333333   0.350606   0.127523         0.335128
#
#    g_intensity_overlap  g_area_over_bf
# 0                  NaN        0.215151
# 1                  NaN        0.300766
# 2                  NaN        0.357552
# 3                  NaN        0.436582
# 4             0.449591        0.219322
#   <div id="f5f92af2-aecc-4b6f-82ff-a4b3f6999981" data-root-id="p1137" style="display: contents;"></div>
